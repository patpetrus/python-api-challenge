# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# df.loc[(df['Temperature'] > 70) & (df['Wind Speed'] < 10)]
#nearest airport activity

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities

cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['bluff',
#  'vaini',
#  'albany',
#  'tasiilaq',
#  'busselton',
#  'sentyabrskiy',
#  'norrtalje',
#  'port alfred',
#  'malwan',
#  'vao',
#  'constitucion',
#  'karratha',
#  'cherskiy',
#  'hithadhoo',
#  'yellowknife',
#  'castro',
#  'puerto ayora',
#  'yerofey pavlovich',
#  'coquimbo',
#  'bambous virieux',
#  'oil city',
#  'bengkulu',
#  'bathsheba',
#  'smithers',
#  'sitka',
#  'ushuaia',
#  'torbay',
#  'yomitan',
#  'axim',
#  'krasnoselkup',
#  'punta arenas',
#  'meulaboh',
#  'sao francisco de assis',
#  'siauliai',
#  'illoqqortoormiut',
#  'praia da vitoria',
#  'mataura',
#  'santa rosa',
#  'marigot',
#  'qaanaaq',
#  'saint-francois',
#  'deh rawud',
#  'rikitea',
#  'gewane',
#  'klaksvik',
#  'san policarpo',
#  'upernavik',
#  'lorengau',
#  'kuching',
#  'sun city',
#  'atuona',
#  'hobart',
#  'portalegre',
#  'aklavik',
#  'acapulco',
#  'hihifo',
#  'evensk',
#  'butaritari',
#  'hermanus',
#  'trelew',
#  'timmins',
#  'cidreira',
#  'arbagar',
#  'jiancheng',
#  'cape town',
#  'quelimane',
#  'new norfolk',
#  'birao',
#  'tsihombe',
#  'the pas',
#  'uarini',
#  'port said',
#  'jamestown',
#  'mar del plata',
#  'dikson',
#  'kruisfontein',
#  'amderma',
#  'sajokaza',
#  'jardanhaza',
#  'georgetown',
#  'tabou',
#  'marystown',
#  'vanimo',
#  'tessalit',
#  'lebu',
#  'nanortalik',
#  'merauke',
#  'naze',
#  'port hardy',
#  'capaci',
#  'nizhneivkino',
#  'hilo',
#  'faanui',
#  'sahrak',
#  'seydisehir',
#  'rio gallegos',
#  'itaituba',
#  'geraldton',
#  'iqaluit',
#  'saint-philippe',
#  'clyde river',
#  'khatanga',
#  'souillac',
#  'ancud',
#  'barrow',
#  'kreminna',
#  'kikwit',
#  'umm durman',
#  'nizhneyansk',
#  'chara',
#  'caravelas',
#  'mitsamiouli',
#  'manyana',
#  'fuling',
#  'makakilo city',
#  'yalchiki',
#  'thompson',
#  'chicama',
#  'namibe',
#  'severo-kurilsk',
#  'laguna',
#  'east london',
#  'kolokani',
#  'arraial do cabo',
#  'ketchikan',
#  'kuche',
#  'cabo san lucas',
#  'hofn',
#  'avarua',
#  'pinawa',
#  'nikolskoye',
#  'melilla',
#  'magadi',
#  'manavalakurichi',
#  'alekseyevskoye',
#  'olafsvik',
#  'nouakchott',
#  'jingdezhen',
#  'kodinar',
#  'palabuhanratu',
#  'grindavik',
#  'henties bay',
#  'ribeira grande',
#  'ha giang',
#  'marcona',
#  'guerrero negro',
#  'qasigiannguit',
#  'doka',
#  'lazaro cardenas',
#  'warqla',
#  'baykit',
#  'pevek',
#  'salmo',
#  'extrema',
#  'listvyanka',
#  'pallasovka',
#  'nakamura',
#  'ponta delgada',
#  'brae',
#  'mtwara',
#  'bredasdorp',
#  'taolanaro',
#  'kapaa',
#  'mahebourg',
#  'asadabad',
#  'norman wells',
#  'lavrentiya',
#  'wanning',
#  'hasaki',
#  'fort nelson',
#  'abha',
#  'bud',
#  'tiksi',
#  'zyryanka',
#  'vila velha',
#  'bethel',
#  'tumannyy',
#  'arman',
#  'maragogi',
#  'morehead',
#  'belushya guba',
#  'cayenne',
#  'goundam',
#  'isangel',
#  'coihaique',
#  'bonoua',
#  'longyearbyen',
#  'tuktoyaktuk',
#  'damietta',
#  'ocampo',
#  'sao joao da barra',
#  'qeshm',
#  'zhigansk',
#  'ayorou',
#  'zumarraga',
#  'asfi',
#  'ndele',
#  'kintinku',
#  'shumyachi',
#  'dunedin',
#  'carnarvon',
#  'camacha',
#  'esperance',
#  'duldurga',
#  'aksay',
#  'goderich',
#  'kondinskoye',
#  'luderitz',
#  'agnibilekrou',
#  'lisakovsk',
#  'foumban',
#  'kirovskiy',
#  'chingola',
#  'talnakh',
#  'manthani',
#  'tarkwa',
#  'spitsevka',
#  'juneau',
#  'montepuez',
#  'cloquet',
#  'kamskiye polyany',
#  'ilo',
#  'alofi',
#  'general roca',
#  'belgrade',
#  'pontianak',
#  'abashiri',
#  'hamilton',
#  'pafos',
#  'olinda',
#  'kununurra',
#  'galveston',
#  'grand centre',
#  'saint-augustin',
#  'hudson',
#  'wooster',
#  'aloleng',
#  'hovd',
#  'padang',
#  'constantine',
#  'petropavlovsk-kamchatskiy',
#  'dharapuram',
#  'hualmay',
#  'kango',
#  'saint-pierre',
#  'itoman',
#  'mount isa',
#  'vaitupu',
#  'san vicente',
#  'martapura',
#  'mount gambier',
#  'havre-saint-pierre',
#  'san-pedro',
#  'chokurdakh',
#  'lolua',
#  'saldanha',
#  'port-gentil',
#  'leningradskiy',
#  'port elizabeth',
#  'lompoc',
#  'peniche',
#  'scarborough',
#  'saleaula',
#  'yarmouth',
#  'vila',
#  'kutum',
#  'barentsburg',
#  'lodwar',
#  'roebourne',
#  'tuatapere',
#  'haverfordwest',
#  'kasongo-lunda',
#  'upata',
#  'santa cruz cabralia',
#  'hohhot',
#  'skjervoy',
#  'idaho falls',
#  'hirtshals',
#  'kamenka',
#  'tavira',
#  'kodiak',
#  'gallup',
#  'emerald',
#  'beloomut',
#  'port lincoln',
#  'nhulunbuy',
#  'mahadday weyne',
#  'naftah',
#  'paita',
#  'nisia floresta',
#  'fortuna',
#  'belaya gora',
#  'kandrian',
#  'katsuura',
#  'arnhem',
#  'tiarei',
#  'gueret',
#  'raudeberg',
#  'taman',
#  'taltal',
#  'yumen',
#  'medicine hat',
#  'kazalinsk',
#  'dhidhdhoo',
#  'lyngseidet',
#  'katha',
#  'airai',
#  'pisco',
#  'attawapiskat',
#  'lagoa',
#  'savannah bight',
#  'boca do acre',
#  'tzaneen',
#  'kaitangata',
#  'maroantsetra',
#  'coahuayana',
#  'solnechnyy',
#  'brodowski',
#  'parana',
#  'sangar',
#  'papara',
#  'san cristobal',
#  'grand river south east',
#  'saskylakh',
#  'tommot',
#  'aykino',
#  'along',
#  'hukuntsi',
#  'siavonga',
#  'durant',
#  'lincoln',
#  'kawasaki',
#  'ruatoria',
#  'hit',
#  'chapais',
#  'victoria',
#  'muli',
#  'tecoanapa',
#  'qaqortoq',
#  'storforshei',
#  'lunino',
#  'neosho',
#  'pangnirtung',
#  'egvekinot',
#  'khonuu',
#  'noumea',
#  'umm lajj',
#  'datong',
#  'kamaishi',
#  'hambantota',
#  'bandarbeyla',
#  'kumylzhenskaya',
#  'bogovarovo',
#  'esil',
#  'la ronge',
#  'avera',
#  'mehamn',
#  'bushehr',
#  'konibodom',
#  'puerto suarez',
#  'phan thiet',
#  'prince rupert',
#  'kurchum',
#  'beroroha',
#  'mitu',
#  'kinango',
#  'corumba',
#  'miri',
#  'dasoguz',
#  'suntar',
#  'puerto escondido',
#  'mazyr',
#  'pangai',
#  'aksu',
#  'grandview',
#  'lewisville',
#  'tillabery',
#  'palora',
#  'muravlenko',
#  'katangli',
#  'singaraja',
#  'ponta do sol',
#  'casper',
#  'balabac',
#  'bonavista',
#  'buraydah',
#  'san patricio',
#  'isla mujeres',
#  'launceston',
#  'antofagasta',
#  'inhambane',
#  'lata',
#  'peleduy',
#  'sibiti',
#  'shaowu',
#  'jacareacanga',
#  'shimoda',
#  'paracuru',
#  'sao joaquim',
#  'ust-kulom',
#  'araouane',
#  'jaicos',
#  'curumani',
#  'ilulissat',
#  'isparta',
#  'chuy',
#  'quang ngai',
#  'zeya',
#  'kousseri',
#  'narsaq',
#  'maningrida',
#  'vera cruz',
#  'rawson',
#  'ulaangom',
#  'mys shmidta',
#  'blagoyevo',
#  'namatanai',
#  'comodoro rivadavia',
#  'san borja',
#  'ust-tsilma',
#  'vardo',
#  'kavieng',
#  'brownsville',
#  'colares',
#  'payson',
#  'mulege',
#  'maykain',
#  'alepe',
#  'pingliang',
#  'harper',
#  'kuzhener',
#  'banda aceh',
#  'lima',
#  'santa maria',
#  'vaitape',
#  'nouadhibou',
#  'turka',
#  'mechetinskaya',
#  'marsa matruh',
#  'miaoli',
#  'tura',
#  'samusu',
#  'yulara',
#  'northam',
#  'hearst',
#  'lensk',
#  'codrington',
#  'cockburn town',
#  'fonte boa',
#  'lashio',
#  'vinh',
#  'shakhtinsk',
#  'viligili',
#  'samalaeulu',
#  'eucaliptus',
#  'bakchar',
#  'steger',
#  'turulung',
#  'pontivy',
#  'sept-iles',
#  'anadyr',
#  'aykhal',
#  'mersing',
#  'khandyga',
#  'kachiry',
#  'ahuimanu',
#  'portland',
#  'todos santos',
#  'cranbrook',
#  'ambon',
#  'bahir dar',
#  'sao jose da coroa grande',
#  'mayo',
#  'port pirie',
#  'presidencia roque saenz pena',
#  'homer',
#  'dudinka',
#  'beringovskiy',
#  'tanete',
#  'pringsewu',
#  'mpophomeni',
#  'mattru',
#  'verkhnyaya inta',
#  'najran',
#  'dali',
#  'roald',
#  'meadow lake',
#  'halalo',
#  'morganton',
#  'tha mai',
#  'louisbourg',
#  'kastamonu',
#  'kieta',
#  'riom',
#  'chernyshevskiy',
#  'celestun',
#  'bargal',
#  'fare',
#  'porto santo',
#  'lucapa',
#  'deputatskiy',
#  'olavarria',
#  'nuuk',
#  'palmerston',
#  'black river',
#  'bataipora',
#  'labrea',
#  'hof',
#  'sorong',
#  'virginia beach',
#  'polunochnoye',
#  'iskateley',
#  'klyuchi',
#  'coari',
#  'boyolangu',
#  'moose factory',
#  'zhashkiv',
#  'bereza',
#  'guadix',
#  'chuncheng',
#  'jinxiang',
#  'ahome',
#  'sierpc',
#  'nemuro',
#  'neiafu',
#  'gelgaudiskis',
#  'benguela',
#  'svetlaya',
#  'kahului',
#  'minot',
#  'nevel',
#  'boddam',
#  'grao mogol',
#  'kavaratti',
#  'marsh harbour',
#  'nome',
#  'asau',
#  'jumla',
#  'mildura',
#  'hirara',
#  'aksarka',
#  'sabha',
#  'khuzhir',
#  'shingu',
#  'aflu',
#  'rio grande',
#  'tefe',
#  'krasnoborsk',
#  'westport',
#  'gjovik',
#  'solovetskiy',
#  'qui nhon',
#  'kloulklubed',
#  'nushki',
#  'bocas del toro',
#  'bouna',
#  'nguiu',
#  'polyarnyy',
#  'nueva loja',
#  'calvia',
#  'garissa',
#  'torit',
#  'rocha',
#  'fairbanks',
#  'aktash',
#  'mragowo',
#  'tanggu',
#  'bedesa',
#  'leh',
#  'el alto',
#  'saint-joseph',
#  'tunceli',
#  'umm kaddadah',
#  'alta floresta',
#  'wakkanai',
#  'provideniya',
#  'southbridge',
#  'flin flon',
#  'luanda',
#  'pilas',
#  'paamiut',
#  'adrar',
#  'quatre cocos',
#  'half moon bay',
#  'yarensk',
#  'bom jesus',
#  'valdosta',
#  'broken hill',
#  'baruun-urt',
#  'nyurba',
#  'nyrob',
#  'shimanovsk',
#  'nagua',
#  'rusape',
#  'rungata',
#  'togur',
#  'khorixas',
#  'chernyshevsk',
#  'gokak',
#  'saint george',
#  'baiao',
#  'coihueco',
#  'kachikau',
#  'dingle',
#  'becej',
#  'ampanihy',
#  'ganzhou',
#  'iralaya',
#  'namtsy',
#  'west bay',
#  'saint-georges',
#  'cooma',
#  'omboue',
#  'yichun',
#  'yeppoon',
#  'aljezur',
#  'sao miguel do araguaia',
#  'mandalgovi',
#  'talara',
#  'umzimvubu',
#  'sataua',
#  'tonj',
#  'vila franca do campo',
#  'stornoway',
#  'mackay',
#  'bhadra',
#  'bella vista',
#  'vanino',
#  'edd',
#  'talaja',
#  'toliary',
#  'balikpapan',
#  'carmarthen']

# %%
city1 = 'rikitea'

test_url = f"{url}appid={weather_api_key}&q={city1}"
output = requests.get(test_url).json()
output
# Out:
# {'coord': {'lon': -134.9692, 'lat': -23.1203},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 298.66,
#   'feels_like': 298.4,
#   'temp_min': 298.66,
#   'temp_max': 298.66,
#   'pressure': 1011,
#   'humidity': 72,
#   'sea_level': 1011,
#   'grnd_level': 1008},
#  'visibility': 10000,
#  'wind': {'speed': 5.7, 'deg': 123},
#  'clouds': {'all': 7},
#  'dt': 1612384798,
#  'sys': {'country': 'PF', 'sunrise': 1612363269, 'sunset': 1612410378},
#  'timezone': -32400,
#  'id': 4030556,
#  'name': 'Rikitea',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import time
city_name = []
country = []
date = []
lat = []
lng = []
temp = []
humidity = []
wind_speed = []
cloudiness = []

url = "http://api.openweathermap.org/data/2.5/weather?"
for city in cities:
    query_url = f"{url}appid={weather_api_key}&q={city}"
    try:
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        time.sleep(1.1)
        city_name.append(city)
        print(response['name'])
    except KeyError: 
        print('Skipping city...')
# Out:
# Bluff
# Vaini
# Albany
# Tasiilaq
# Busselton
# Skipping city...
# Norrtälje
# Port Alfred
# Skipping city...
# Vao
# Constitución
# Karratha
# Cherskiy
# Hithadhoo
# Yellowknife
# Castro
# Puerto Ayora
# Yerofey Pavlovich
# Coquimbo
# Bambous Virieux
# Oil City
# Bengkulu
# Bathsheba
# Smithers
# Sitka
# Ushuaia
# Torbay
# Skipping city...
# Esim
# Krasnosel'kup
# Punta Arenas
# Meulaboh
# São Francisco de Assis
# Šiauliai
# Skipping city...
# Praia da Vitória
# Mataura
# Santa Rosa
# Marigot
# Qaanaaq
# Saint-François
# Skipping city...
# Rikitea
# Gewanē
# Klaksvík
# San Policarpo
# Upernavik
# Lorengau
# Kuching
# Sun City
# Atuona
# Hobart
# Portalegre
# Aklavik
# Acapulco de Juárez
# Skipping city...
# Evensk
# Butaritari
# Hermanus
# Trelew
# Timmins
# Cidreira
# Arbagar
# Jiancheng
# Cape Town
# Quelimane
# New Norfolk
# Birao
# Skipping city...
# The Pas
# Uarini
# Port Said
# Jamestown
# Mar del Plata
# Dikson
# Kruisfontein
# Skipping city...
# Sajókaza
# Járdánháza
# George Town
# Tabou
# Marystown
# Vanimo
# Tessalit
# Lebu
# Nanortalik
# Merauke
# Naze
# Port Hardy
# Capaci
# Nizhneivkino
# Hilo
# Faanui
# Skipping city...
# Seydişehir
# Río Gallegos
# Itaituba
# Geraldton
# Iqaluit
# Saint-Philippe
# Clyde River
# Khatanga
# Souillac
# Ancud
# Barrow
# Kreminna
# Arrondissement de Riom
# Chernyshevskiy
# Celestún
# Skipping city...
# Fare
# Porto Santo
# Lucapa
# Deputatsky
# Olavarría
# Nuuk
# Palmerston
# Black River
# Bataiporã
# Lábrea
# Hof
# Sorong
# Virginia Beach
# Polunochnoye
# Iskateley
# Klyuchi
# Coari
# Boyolangu
# Moose Factory
# Zhashkiv
# Bereza
# Guadix
# Chuncheng
# Jinxiang
# Ahome
# Sierpc
# Nemuro
# Neiafu
# Gelgaudiškis
# Benguela
# Svetlaya
# Kahului
# Minot
# Nevel'
# Boddam
# Grão Mogol
# Kavaratti
# Marsh Harbour
# Nome
# Asău
# Jumla
# Mildura
# Hirara
# Aksarka
# Sabha
# Khuzhir
# Shingū
# Skipping city...
# Rio Grande
# Tefé
# Krasnoborsk
# Westport
# Gjøvik
# Skipping city...
# Qui Nhon
# Kloulklubed
# Nushki
# Bocas del Toro
# Bouna
# Skipping city...
# Polyarny
# Nueva Loja
# Calvià
# Garissa
# Torit
# Rocha
# Fairbanks
# Aktash
# Mrągowo
# Taku
# Bedēsa
# Leh
# El Alto
# Saint-Joseph
# Tunceli
# Umm Kaddadah
# Alta Floresta
# Wakkanai
# Provideniya
# Southbridge
# Flin Flon
# Luanda
# Pilas
# Paamiut
# Adrar
# Quatre Cocos
# Half Moon Bay
# Yarensk
# Bom Jesus
# Valdosta
# Broken Hill
# Baruun-Urt
# Nyurba
# Nyrob
# Shimanovsk
# Nagua
# Rusape
# Skipping city...
# Togur
# Khorixas
# Chernyshevsk
# Gokak
# Saint George
# Baião
# Coihueco
# Skipping city...
# Dingle
# Bečej
# Ampanihy
# Ganzhou
# Iralaya
# Namtsy
# West Bay
# St. George's
# Cooma
# Omboué
# Yichun
# Yeppoon
# Aljezur
# São Miguel do Araguaia
# Mandalgovi
# Talara
# Skipping city...
# Skipping city...
# Tonj
# Vila Franca do Campo
# Stornoway
# Mackay
# Bhādra
# Bella Vista
# Vanino
# Edd
# Talāja
# Skipping city...
# Balikpapan
# Carmarthen

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#city_total_df must take cities and output only the data from city_names. cities has all humidity, temp, etc. data.
cities_df = pd.DataFrame({'City': city_name, 
                          'Country': country, 
                          'Date': date, 
                          'Latitude': lat, 
                          'Longitude': lng, 
                          'Temperature': temp, 
                          'Humidity': humidity, 
                          'Wind Speed': wind_speed, 
                          'Cloudiness': cloudiness})
cities_df.head()
# Out:
#         City Country        Date  Latitude  Longitude  Temperature  Humidity  \
# 0      bluff      NZ  1612384829  -46.6000   168.3333       284.96        67
# 1      vaini      TO  1612384830  -21.2000  -175.2000       300.15        89
# 2     albany      US  1612384831   42.6001   -73.9662       272.59        67
# 3   tasiilaq      GL  1612384665   65.6145   -37.6368       270.70        97
# 4  busselton      AU  1612384663  -33.6500   115.3333       283.71        81
#
#    Wind Speed  Cloudiness
# 0        6.87          49
# 1        1.03          75
# 2        6.26         100
# 3       12.81         100
# 4        7.45           0

# %%
#use this csv for vacation py!!!!!
cities_df.to_csv('city_clean.csv')

# %%
cities_df.describe()
# Out:
#                Date    Latitude   Longitude  Temperature    Humidity  \
# count  5.840000e+02  584.000000  584.000000   584.000000  584.000000
# mean   1.612385e+09   21.514401   13.448252   282.935805   73.770548
# std    2.244717e+02   33.059279   89.596774    18.326126   20.100914
# min    1.612384e+09  -54.800000 -179.166700   225.020000   10.000000
# 25%    1.612385e+09   -5.935250  -65.406950   272.150000   64.000000
# 50%    1.612385e+09   26.712250   19.851200   288.290000   78.000000
# 75%    1.612385e+09   50.074800   95.523775   298.150000   89.000000
# max    1.612386e+09   78.218600  179.316700   309.000000  100.000000
#
#        Wind Speed  Cloudiness
# count  584.000000  584.000000
# mean     3.779007   54.881849
# std      2.769363   39.325986
# min      0.120000    0.000000
# 25%      1.725000   12.000000
# 50%      3.090000   70.000000
# 75%      5.140000   91.250000
# max     19.410000  100.000000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
hum_cities = cities_df.loc[cities_df["Humidity"] > 100]
hum_cities
# Out:
# Empty DataFrame
# Columns: [City, Country, Date, Latitude, Longitude, Temperature, Humidity, Wind Speed, Cloudiness]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df['Latitude'], cities_df['Temperature'], alpha = .75)
plt.savefig('Lat_Temp.png')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df['Latitude'], cities_df['Humidity'])
plt.savefig('Lat_Hum.png')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df['Latitude'], cities_df['Cloudiness'])
plt.savefig('Lat_Cloud.png')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness')
plt.grid()
plt.show()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df['Latitude'], cities_df['Wind Speed'])
plt.savefig('Lat_Wind.png')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title('City Latitude cs. Wind Speed')
plt.grid()
plt.show()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
s_df = cities_df.loc[cities_df['Latitude'] < 0]
n_df = cities_df.loc[cities_df['Latitude'] >= 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = n_df['Latitude']
y_values = n_df['Temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (25,230), fontsize = 10, color="red")
plt.xlabel('Latutude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = s_df['Latitude']
y_values = s_df['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30, 285),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = n_df['Latitude']
y_values = n_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = s_df['Latitude']
y_values = s_df['Temperature']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30, 285),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = n_df['Latitude']
y_values = n_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = s_df['Latitude']
y_values = s_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, 10),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = n_df['Latitude']
y_values = n_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,15),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = s_df['Latitude']
y_values = s_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,2),fontsize=15,color="red")
plt.xlabel('Latutude')
plt.ylabel('Cloudiness')
plt.show()
